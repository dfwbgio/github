# %% [markdown]
# cv2라이브러리를 이용해서 이미지의 테두리만 추출하기
# =========

# %% [markdown]
# ###cv2 라이브러리 호출

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# ##*드라이브 마운트*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 사진 호출하기
# 1. imread()
# 2. imshow()

# %%
img = '사진1.jpg'
image = cv2.imread(img)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=634x406>

# %% [markdown]
# ######원본사진
# [원본사진](https://search.pstatic.net/sunny/?src=https%3A%2F%2Fi.namu.wiki%2Fi%2FKiruztAbHpJgUCrWl8paWALTzXhLe99xZDS8APPtMOGRWA8ILZQcfIBb2GZlI-crs3KoHH4xZBH_qnh_9GsiRQ.webp&type=sc960_832)

# %% [markdown]
# ##원본 이미지에서 __테두리__만 추출하기

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
canny=cv2.Canny(gray, 100, 210)
cv2_imshow(canny)
# Out:
# <PIL.Image.Image image mode=L size=634x406>
